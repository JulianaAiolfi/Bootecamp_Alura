# %% [markdown]
# <a href="https://colab.research.google.com/github/JulianaAiolfi/Bootecamp_Alura/blob/main/Modulo_01/notebooks/Aula_04_Modulo_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula_04 Análise de gráficos e criação de hipótese

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import ticker
from matplotlib import cm
import numpy as np
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
dados = pd.read_csv('https://raw.githubusercontent.com/JulianaAiolfi/Bootecamp_Alura/main/Modulo_01/dados/SUS_atendimento_valor_anomes_unidfederacao.csv',
                    encoding='ISO-8859-1',skiprows=3, sep=';', skipfooter=12,
                    thousands='.', decimal=',')

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0, 'Unidade da Federação')

# %%
usaveis = dados[colunas_usaveis]
usaveis = usaveis.set_index('Unidade da Federação')

# %%
usaveis.sort_values('Total', ascending=False)

#Desta forma conseguimos visualizar pela ondem de gastos
# Out:
#                          2007/Ago   2007/Set  ...     2021/Jul          Total
# Unidade da Federação                          ...
# 35 São Paulo           1665349.90 4434168.64  ... 164662041.50 43433962300.53
# 31 Minas Gerais         971394.37 2861781.50  ...  78465417.06 21472877412.32
# 41 Paraná               554800.22 1431708.01  ...  45253506.54 15366468888.79
# 43 Rio Grande do Sul   1049252.33 3182913.14  ...  30830915.24 13358781469.20
# 33 Rio de Janeiro       469469.34  921646.57  ...  44385763.24 10860190737.19
# 29 Bahia                135146.36  448349.75  ...  33066773.22 10284138031.12
# 26 Pernambuco           400640.85 1088340.42  ...  40710905.85  9055432868.74
# 42 Santa Catarina       693955.05 1092964.12  ...  19905781.52  8217647599.39
# 23 Ceará                357904.65  572356.18  ...  20290962.12  6961352252.48
# 52 Goiás                179395.82  418053.58  ...  22832314.13  5238239197.40
# ...

# %%
ordenado_por_total = usaveis.sort_values('Total', ascending=False) #criando uma nova variavel
ordenado_por_total = ordenado_por_total.drop('Total', axis=1) #deletando as coluna total, para ficar somente com a ordem dos gastos que mais gastaram
ordenado_por_total.head()
# Out:
#                        2007/Ago   2007/Set  ...     2021/Jun     2021/Jul
# Unidade da Federação                        ...
# 35 São Paulo         1665349.90 4434168.64  ... 397170231.42 164662041.50
# 31 Minas Gerais       971394.37 2861781.50  ... 178069022.08  78465417.06
# 41 Paraná             554800.22 1431708.01  ... 112190739.32  45253506.54
# 43 Rio Grande do Sul 1049252.33 3182913.14  ...  99770926.56  30830915.24
# 33 Rio de Janeiro     469469.34  921646.57  ...  87873583.50  44385763.24
#
# [5 rows x 168 columns]

# %%
colunas_interessadas = ordenado_por_total.columns[6:]
ordenado_por_total = ordenado_por_total[colunas_interessadas]

#Retirando as 6 primeiras colunas Fev/2008 a Jan/2008

# %%
ordenado_por_total = ordenado_por_total / 1000000
ordenado_por_total.head(5).T.plot(figsize=(10,6))

# %%
meses_filtrados = ordenado_por_total.columns[47:150]
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))

# %%
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %%
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))
plt.ylim(100, 350)
# Out:
# (100.0, 350.0)

# %%
ordenado_por_total[ordenado_por_total.columns[-12:]].head(3).T.plot(figsize=(10,6))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %%
ordenado_por_total[ordenado_por_total.columns[-24:]].head(3).T.plot(figsize=(10,6))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %%
ordenado_por_total[ordenado_por_total.columns[-36:]].head(3).T.plot(figsize=(10,6))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %%
ordenado_por_total[ordenado_por_total.columns[-60:]].head(3).T.plot(figsize=(10,6))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %%
ordenado_por_total.head(5).T.plot(figsize=(10,6))

# %%
ordenado_por_total.head(5).T.plot(figsize=(6,6))

# %%
ordenado_por_total.head(5).T.plot(figsize=(20,6))
